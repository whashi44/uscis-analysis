# %% [markdown]
# # Data analysis portion

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("test.csv")
df = df.replace("--",np.nan)
df.head()
# Out:
#        Posted by    Comments I-485 Status Citizenship Country I-485 Wait Time  \
# 0       calabaza  0 Comments     Approved            Colombia             NaN
# 1     anmomo0000  0 Comments      Pending               China         89 Days
# 2  aruna.apsangi  0 Comments      Pending               India        255 Days
# 3        vrp0001  0 Comments     Approved               India             NaN
# 4       mkrishn2  0 Comments     Approved               India             NaN
#
#   EAD Approval Wait Time AP Approval Wait Time Greencard Processing Time  \
# 0                    NaN                   NaN                  777 Days
# 1                    NaN                   NaN                 1005 Days
# 2                    NaN                   NaN                  173 Days
# 3               283 Days              283 Days                 1236 Days
# 4                    NaN                   NaN                  913 Days
#
#   I-485 Status Date Category  ... EAD Approval Date AP Applied  \
# 0        11/17/2021      IR1  ...               NaN        NaN
# 1        09/29/2021      EB3  ...               NaN        Yes
# 2        05/04/2021     EB1C  ...               NaN        NaN
# 3        10/05/2021     EB1B  ...        08/03/2021        Yes
# 4        06/11/2021     EB1C  ...               NaN        Yes
#
#   AP Application Date AP Receipt Number AP Approval Date Most Recent LUD  \
# 0                 NaN               NaN              NaN             NaN
# 1          09/28/2021               NaN              NaN             NaN
# 2                 NaN               NaN              NaN             NaN
# 3          10/24/2020               NaN       08/03/2021             NaN
# 4          04/06/2021     MSC2191140xxx              NaN      08/31/2021
#
#                                          Date Added  \
# 0  {{'2021-05-26 17:54:30.0' | formatDateWithZone}}
# 1  {{'2021-09-29 15:51:48.0' | formatDateWithZone}}
# 2  {{'2021-05-04 22:59:13.0' | formatDateWithZone}}
# 3  {{'2021-10-06 21:52:18.0' | formatDateWithZone}}
# 4  {{'2021-09-07 19:04:35.0' | formatDateWithZone}}
#
#                                        Last Updated  \
# 0  {{'2021-11-17 21:14:03.0' | formatDateWithZone}}
# 1  {{'2021-11-09 13:20:45.0' | formatDateWithZone}}
# 2  {{'2021-11-02 12:35:29.0' | formatDateWithZone}}
# 3  {{'2021-10-14 20:42:20.0' | formatDateWithZone}}
# 4  {{'2021-09-13 16:20:58.0' | formatDateWithZone}}
#
#                                                Notes \nTracker Actions\n
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2  I485J - Receipt Notice - 10/15/21 received on ...                 NaN
# 3                                                NaN                 NaN
# 4  Recv'd 485J receipt notice - 8/31/2021485 New ...                 NaN
#
# [5 rows x 52 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 52 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Posted by                        30 non-null     object
#  1   Comments                         30 non-null     object
#  2   I-485 Status                     30 non-null     object
#  3   Citizenship Country              30 non-null     object
#  4   I-485 Wait Time                  21 non-null     object
#  5   EAD Approval Wait Time           10 non-null     object
#  6   AP Approval Wait Time            8 non-null      object
#  7   Greencard Processing Time        15 non-null     object
#  8   I-485 Status Date                15 non-null     object
#  9   Category                         30 non-null     object
#  10  Chargeability Country            30 non-null     object
#  11  Applicant Type                   26 non-null     object
#  12  Service Center                   30 non-null     object
#  13  Priority Date                    30 non-null     object
#  14  Application Filed Date           30 non-null     object
#  15  Application Delivered Date       14 non-null     object
#  16  Check Cashed Date                10 non-null     object
#  17  USCIS Receipt Date               30 non-null     object
#  18  Receipt Number                   11 non-null     object
#  19  USCIS Notice Date                18 non-null     object
#  20  I-140/I-485 Filing               30 non-null     object
#  21  I-140 Processing Type            30 non-null     object
#  22  I-140 Approval Date              16 non-null     object
#  23  RFE Received                     13 non-null     object
#  24  RFE Received Date                6 non-null      object
#  25  RFE Reason                       5 non-null      object
#  26  RFE Reply Date                   6 non-null      object
#  27  First Fingerprint Date           18 non-null     object
#  28  Second Fingerprint Date          0 non-null      float64
#  29  Fingerprint Processing Duration  18 non-null     object
#  30  Case Transferred To              4 non-null      object
#  31  Case Transfer Date               3 non-null      object
#  32  Name Check Status                0 non-null      float64
#  33  Name Check Status Date           0 non-null      float64
#  34  Interview Notice Received Date   5 non-null      object
#  35  Interview Date                   5 non-null      object
#  36  Interview Location               5 non-null      object
#  37  Card Ordered Date                4 non-null      object
#  38  Card Receipt Date                2 non-null      object
#  39  EAD Applied                      18 non-null     object
#  40  EAD Application Date             18 non-null     object
#  41  EAD Receipt Number               6 non-null      object
#  42  EAD Approval Date                11 non-null     object
#  43  AP Applied                       16 non-null     object
#  44  AP Application Date              15 non-null     object
#  45  AP Receipt Number                5 non-null      object
#  46  AP Approval Date                 9 non-null      object
#  47  Most Recent LUD                  3 non-null      object
#  48  Date Added                       30 non-null     object
#  49  Last Updated                     30 non-null     object
#  50  Notes                            5 non-null      object
#  51
# Tracker Actions
#                 0 non-null      float64
# dtypes: float64(4), object(48)
# memory usage: 12.3+ KB

# %%
df["Greencard Processing Time"] = df["Greencard Processing Time"].astype(str)
split_function = lambda x: x.split()[0]
df["Greencard Processing Time"] = df["Greencard Processing Time"].apply(split_function)
# df["Greencard Processing Time"]

# %%
df["Greencard Processing Time"].astype(float).describe()
# Out:
# count      15.000000
# mean     1217.266667
# std      1365.104678
# min        43.000000
# 25%       364.000000
# 50%       777.000000
# 75%      1120.500000
# max      4084.000000
# Name: Greencard Processing Time, dtype: float64
